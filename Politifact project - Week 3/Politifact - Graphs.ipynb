# %%
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import scipy
import seaborn as sns
import matplotlib.style as style
import matplotlib

# %%
df = pd.read_csv("politifacts_score_freq.csv")

# %%
df.head()
# Out:
#    Year         Score  Count    Percent
# 0  2007          True     70  29.411765
# 1  2007     Half-True     55  23.109244
# 2  2007   Mostly True     43  18.067227
# 3  2007         False     34  14.285714
# 4  2007  Mostly False     26  10.924370

# %%
# df.transpose()

graph_df = df.pivot(index='Year', columns='Score', values='Percent')
graph_df
# Out:
# Score      False  Half-True  Mostly False  Mostly True  Pants on Fire!  \
# Year
# 2007   14.285714  23.109244     10.924370    18.067227        4.201681
# 2008   19.064125  17.331023     14.731369    15.597920        6.759099
# 2009   25.225225  17.117117     13.738739    13.963964        9.684685
# 2010   19.209040  21.594476     14.752040    15.630885        9.290647
# 2011   20.758585  18.657099     14.556638    18.503332        8.405946
# 2012   19.131752  21.554770     17.163049    16.506815        8.177688
# 2013   15.325936  21.567268     16.158114    22.607490        7.212205
# 2014   18.303571  18.750000     18.239796    21.237245        8.928571
# 2015   16.436252  18.894009     18.356375    23.118280        7.373272
# 2016   17.865297  20.547945     18.150685    21.404110        8.961187
# 2017   18.174666  15.971676     16.837136    16.837136       22.816680
# 2018   22.413793  16.954023     19.252874    13.577586       18.750000
# ...

# %%
graph_df[['Pants on Fire!', 'True']].plot()

# %%
ax = graph_df.plot(figsize=(20,10),linewidth='3', alpha=0.5)

graph_df.plot(ax=ax).f
